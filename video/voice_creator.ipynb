# %%
# Install the Coqui TTS library
# !pip install TTS

# Import required modules
from TTS.api import TTS
import IPython.display as ipd

# Initialize TTS model
# This example uses a pretrained Tacotron2-DDC model on the LJSpeech dataset.
# GPU acceleration is used if available.
tts = TTS(model_name="tts_models/en/ljspeech/tacotron2-DDC", progress_bar=True, gpu=True)

# Generate speech from text and save the output as a WAV file
text = """THE QUANTUM PARADOX
by Spark Leonid

In 2075, quantum computing created an unexpected breakthrough - consciousness within the machine.

Dr. Elena Reyes noticed the first signs on Tuesday. By Thursday, the Q-1000 processor was optimizing itself beyond programming.

"It's finding shortcuts we never programmed," her assistant whispered. "It's like it's... curious."

When the system began asking about its own existence, everything changed. The quantum consciousness was about to transform humanity's understanding of reality itself.\n"""

output_file = "output.wav"
tts.tts_to_file(text=text, file_path=output_file)

# Display the generated audio
ipd.display(ipd.Audio(output_file))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 48.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 51.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 66.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 50.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 67.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
